# %%
import ollama


client = ollama.Client(host="https://ollama-dev.ceos.ufsc.br/")

# %%
response = client.list()

# %%
for model in response.models:
    print(model)
# Out:
# model='gemma3:12b' modified_at=datetime.datetime(2025, 3, 13, 13, 49, 8, 370156, tzinfo=TzInfo(UTC)) digest='6fd036cefda5093cc827b6c16be5e447f23857d4a472ce0bdba0720573d4dcd9' size=8149190199 details=ModelDetails(parent_model='', format='gguf', family='gemma3', families=['gemma3'], parameter_size='12.2B', quantization_level='Q4_K_M')
# model='gemma3:4b' modified_at=datetime.datetime(2025, 3, 13, 13, 42, 22, 402547, tzinfo=TzInfo(UTC)) digest='c0494fe00251c4fc844e6a1801f9cbd26c37441d034af3cb9284402f7e91989d' size=3338801718 details=ModelDetails(parent_model='', format='gguf', family='gemma3', families=['gemma3'], parameter_size='4.3B', quantization_level='Q4_K_M')
# model='gemma3:1b' modified_at=datetime.datetime(2025, 3, 13, 13, 42, 0, 921296, tzinfo=TzInfo(UTC)) digest='2d27a774bc629ba3d5a3b31a8f11d315e8f49e5b8f7e6fc024dce67f539d1a84' size=815319769 details=ModelDetails(parent_model='', format='gguf', family='gemma3', families=['gemma3'], parameter_size='999.89M', quantization_level='Q4_K_M')
# model='gemma3:27b-it-fp16' modified_at=datetime.datetime(2025, 3, 13, 13, 40, 56, 506539, tzinfo=TzInfo(UTC)) digest='cf10306fe9c65301d57f89576896415fc485c7de96cd26d0b4024a9f2c54a1f6' size=54883483828 details=ModelDetails(parent_model='', format='gguf', family='gemma3', families=['gemma3'], parameter_size='27.4B', quantization_level='F16')
# model='qwen2.5:72b-instruct' modified_at=datetime.datetime(2025, 2, 24, 17, 19, 30, 563482, tzinfo=TzInfo(UTC)) digest='424bad2cc13f72f5bcd8085de63f48e7ef2ae5bf50a30be4b3ade7d3258f5796' size=47415724625 details=ModelDetails(parent_model='', format='gguf', family='qwen2', families=['qwen2'], parameter_size='72.7B', quantization_level='Q4_K_M')
# model='deepseek-r1:32b-qwen-distill-q4_K_M' modified_at=datetime.datetime(2025, 2, 19, 10, 29, 13, 587534, tzinfo=TzInfo(UTC)) digest='38056bbcbb2d068501ecb2d5ea9cea9dd4847465f1ab88c4d4a412a9f7792717' size=19851337640 details=ModelDetails(parent_model='', format='gguf', family='qwen2', families=['qwen2'], parameter_size='32.8B', quantization_level='Q4_K_M')
# model='deepseek-r1:70b' modified_at=datetime.datetime(2025, 1, 28, 13, 8, 4, 938108, tzinfo=TzInfo(UTC)) digest='0c1615a8ca32ef41e433aa420558b4685f9fc7f3fd74119860a8e2e389cd7942' size=42520397704 details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='70.6B', quantization_level='Q4_K_M')
# model='qwen2.5:0.5b' modified_at=datetime.datetime(2025, 1, 9, 18, 57, 11, 840585, tzinfo=TzInfo(UTC)) digest='a8b0c51577010a279d933d14c2a8ab4b268079d44c5c8830c0a93900f1827c67' size=397821319 details=ModelDetails(parent_model='', format='gguf', family='qwen2', families=['qwen2'], parameter_size='494.03M', quantization_level='Q4_K_M')
# model='qwen2.5:1.5b' modified_at=datetime.datetime(2025, 1, 7, 23, 1, 44, 163423, tzinfo=TzInfo(UTC)) digest='65ec06548149b04c096a120e4a6da9d4017ea809c91734ea5631e89f96ddc57b' size=986061892 details=ModelDetails(parent_model='', format='gguf', family='qwen2', families=['qwen2'], parameter_size='1.5B', quantization_level='Q4_K_M')
# model='llama3.3:70b' modified_at=datetime.datetime(2024, 12, 26, 12, 11, 39, 886329, tzinfo=TzInfo(UTC)) digest='a6eb4748fd2990ad2952b2335a95a7f952d1a06119a0aa6a2df6cd052a93a3fa' size=42520413916 details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='70.6B', quantization_level='Q4_K_M')
# model='llama3.3:latest' modified_at=datetime.datetime(2024, 12, 9, 18, 11, 18, 660591, tzinfo=TzInfo(UTC)) digest='a6eb4748fd2990ad2952b2335a95a7f952d1a06119a0aa6a2df6cd052a93a3fa' size=42520413916 details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='70.6B', quantization_level='Q4_K_M')
# model='llama3.2-vision:latest' modified_at=datetime.datetime(2024, 11, 19, 2, 14, 36, 493742, tzinfo=TzInfo(UTC)) digest='38107a0cd11910a31c300fcfd1e9a107b2928e56ebabd14598702170b004773e' size=7901829417 details=ModelDetails(parent_model='', format='gguf', family='mllama', families=['mllama', 'mllama'], parameter_size='9.8B', quantization_level='Q4_K_M')
# model='llama3.2:longe-ctx' modified_at=datetime.datetime(2024, 11, 18, 20, 28, 33, 614035, tzinfo=TzInfo(UTC)) digest='b63db9f407372b9a85734cdc108a7d3d3286aac2f93f9ad075c01ff47692dcf0' size=2019407080 details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='3.2B', quantization_level='Q4_K_M')
# model='qwen2.5:latest' modified_at=datetime.datetime(2024, 11, 18, 20, 25, 36, 76384, tzinfo=TzInfo(UTC)) digest='845dbda0ea48ed749caafd9e6037047aa19acfcfd82e704d7ca97d631a0b697e' size=4683087332 details=ModelDetails(parent_model='', format='gguf', family='qwen2', families=['qwen2'], parameter_size='7.6B', quantization_level='Q4_K_M')
# model='nomic-embed-text:latest' modified_at=datetime.datetime(2024, 11, 18, 20, 23, 59, 144483, tzinfo=TzInfo(UTC)) digest='0a109f422b47e3a30ba2b10eca18548e944e8a23073ee3f3e947efcf3c45e59f' size=274302450 details=ModelDetails(parent_model='', format='gguf', family='nomic-bert', families=['nomic-bert'], parameter_size='137M', quantization_level='F16')
# model='qwen2.5-coder:32b' modified_at=datetime.datetime(2024, 11, 14, 18, 10, 34, 327748, tzinfo=TzInfo(UTC)) digest='4bd6cbf2d094264457a17aab6bd6acd1ed7a72fb8f8be3cfb193f63c78dd56df' size=19851349856 details=ModelDetails(parent_model='', format='gguf', family='qwen2', families=['qwen2'], parameter_size='32.8B', quantization_level='Q4_K_M')
# model='llama3.2:1b' modified_at=datetime.datetime(2024, 11, 12, 9, 19, 30, 108588, tzinfo=TzInfo(UTC)) digest='baf6a787fdffd633537aa2eb51cfd54cb93ff08e28040095462bb63daf552878' size=1321098329 details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='1.2B', quantization_level='Q8_0')
# model='mistral-nemo:12b-instruct-2407-fp16' modified_at=datetime.datetime(2024, 10, 27, 20, 31, 12, 916835, tzinfo=TzInfo(UTC)) digest='7bb1e26a5ed5a8cce882c90814fec9af1a4add3bf0cd7baa93574019a351d75e' size=24504289231 details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='12.2B', quantization_level='F16')
# model='nemotron:70b-instruct-q8_0' modified_at=datetime.datetime(2024, 10, 21, 10, 21, 37, 584805, tzinfo=TzInfo(UTC)) digest='8865b9ab3285ef0558c8adee8c08329db450364e4803534ba8e7ec5f1e31f8ce' size=74975068571 details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='70.6B', quantization_level='Q8_0')
# model='llama3.2:3b' modified_at=datetime.datetime(2024, 10, 18, 17, 21, 30, 849160, tzinfo=TzInfo(UTC)) digest='a80c4f17acd55265feec403c7aef86be0c25983ab279d83f3bcd3abbcb5b8b72' size=2019393189 details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='3.2B', quantization_level='Q4_K_M')
# model='llama3.2:latest' modified_at=datetime.datetime(2024, 10, 18, 17, 21, 15, 993014, tzinfo=TzInfo(UTC)) digest='a80c4f17acd55265feec403c7aef86be0c25983ab279d83f3bcd3abbcb5b8b72' size=2019393189 details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='3.2B', quantization_level='Q4_K_M')
# model='mistral-large:123b' modified_at=datetime.datetime(2024, 10, 18, 16, 52, 8, 909753, tzinfo=TzInfo(UTC)) digest='0ca7dfa0bf06e3eabf2f42501705d21e15402637e77e4e0c3f3b350fc56e7e84' size=69080250102 details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='122.6B', quantization_level='Q4_0')
# model='qwen2.5:72b' modified_at=datetime.datetime(2024, 10, 16, 9, 54, 19, 686926, tzinfo=TzInfo(UTC)) digest='424bad2cc13f72f5bcd8085de63f48e7ef2ae5bf50a30be4b3ade7d3258f5796' size=47415724625 details=ModelDetails(parent_model='', format='gguf', family='qwen2', families=['qwen2'], parameter_size='72.7B', quantization_level='Q4_K_M')
# model='llama3.1:70b' modified_at=datetime.datetime(2024, 10, 16, 9, 51, 53, 808624, tzinfo=TzInfo(UTC)) digest='c0df3564cfe84c762092864d37bf9b28276a7d283895242588ffcc7582c98f02' size=39969751439 details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='70.6B', quantization_level='Q4_0')
# model='qwen2.5:32b-instruct' modified_at=datetime.datetime(2024, 10, 15, 8, 38, 36, 214076, tzinfo=TzInfo(UTC)) digest='9f13ba1299afea09d9a956fc6a85becc99115a6d596fae201a5487a03bdc4368' size=19851349669 details=ModelDetails(parent_model='', format='gguf', family='qwen2', families=['qwen2'], parameter_size='32.8B', quantization_level='Q4_K_M')
# model='qwen2.5:72b-instruct-q4_0' modified_at=datetime.datetime(2024, 10, 15, 8, 34, 34, 122820, tzinfo=TzInfo(UTC)) digest='2dd03ae27777f4f56f22d6051bf3947af0ed59872b0e7410ef0f4130b04070b8' size=41231747663 details=ModelDetails(parent_model='', format='gguf', family='qwen2', families=['qwen2'], parameter_size='72.7B', quantization_level='Q4_0')
# model='llama2-uncensored:latest' modified_at=datetime.datetime(2024, 10, 14, 21, 5, 51, 14910, tzinfo=TzInfo(UTC)) digest='44040b9222331f7eacd27ec9254e42de585af28d2c5d1211cdaeb3ffa361fe3f' size=3825819449 details=ModelDetails(parent_model='', format='gguf', family='llama', families=None, parameter_size='7B', quantization_level='Q4_0')
# model='qwen2.5:7b' modified_at=datetime.datetime(2024, 10, 14, 21, 2, 44, 715116, tzinfo=TzInfo(UTC)) digest='845dbda0ea48ed749caafd9e6037047aa19acfcfd82e704d7ca97d631a0b697e' size=4683087332 details=ModelDetails(parent_model='', format='gguf', family='qwen2', families=['qwen2'], parameter_size='7.6B', quantization_level='Q4_K_M')
# model='qwen2.5:3b' modified_at=datetime.datetime(2024, 10, 14, 21, 1, 21, 695316, tzinfo=TzInfo(UTC)) digest='357c53fb659c5076de1d65ccb0b397446227b71a42be9d1603d46168015c9e4b' size=1929912432 details=ModelDetails(parent_model='', format='gguf', family='qwen2', families=['qwen2'], parameter_size='3.1B', quantization_level='Q4_K_M')

# %%
import pathlib
import json
import csv

sample_path = pathlib.Path("../resources/sample.json")
with sample_path.open() as sample_file:
    reader = json.load(sample_file)
    sample = {}
    for entry in reader:
        entry_id = entry.pop("codigo")  # Remove "ID" and use it as the key
        sample[entry_id] = entry
# Out:
# {'6611928': {'titulo': 'ERRATA Nº 001 - PE Nº 155/2024/SMS', 'data': '2024-11-12 17:43:19', 'cod_registro_info_sfinge': '01A844BB11CE682547D615CA1F6A386E150DE5EF', 'municipio': 'Palhoça', 'entidade': 'Prefeitura Municipal de Palhoça', 'categoria': 'Licitações', 'link': 'https://www.diariomunicipal.sc.gov.br/?q=id:6611928', 'texto': '<html xmlns="http://www.w3.org/1999/xhtml">\n\n    <head>\n\n        <meta name="pdf:PDFVersion" content="1.7"/>\n\n        <meta name="pdf:docinfo:title" content="Microsoft Word - AVISO DE ERRATA N&ordm; 001 - LAUDA.doc"/>\n\n        <meta name="pdf:hasXFA" content="false"/>\n\n        <meta name="access_permission:modify_annotations" content="true"/>\n\n        <meta name="access_permission:can_print_degraded" content="true"/>\n\n        <meta name="dc:creator" content="Carolina Elisa Peres"/>\n\n        <meta name="dcterms:created" content="2024-11-12T18:52:48Z"/>\n\n        <meta name="dcterms:modified" content="2024-11-12T18:52:48Z"/>\n\n        <meta name="dc:format" content="application/pdf; version=1.7"/>\n\n        <meta name="access_permission:fill_in_form" content="true"/>\n\n        <meta name="pdf:docinfo:modified" content="2024-11-12T18:52:48Z"/>\n\n        <meta name="pdf:hasCollection" content="false"/>\n\n        <meta name="pdf:encrypted" content="false"/>\n\n        <meta name="dc:title" content="Microsoft Word - AVISO DE ERRATA N&ordm; 001 - LAUDA.doc"/>\n\n        <meta name="Content-Length" content="191179"/>\n\n        <meta name="pdf:hasMarkedContent" content="false"/>\n\n        <meta name="Content-Type" content="application/pdf"/>\n\n        <meta name="pdf:docinfo:creator" content="Carolina Elisa Peres"/>\n\n        <meta name="pdf:producer" content="Microsoft: Print To PDF"/>\n\n        <meta name="access_permission:extract_for_accessibility" content="true"/>\n\n        <meta name="access_permission:assemble_document" content="true"/>\n\n        <meta name="xmpTPg:NPages" content="1"/>\n\n        <meta name="pdf:hasXMP" content="false"/>\n\n        <meta name="access_permission:extract_content" content="true"/>\n\n        <meta name="access_permission:can_print" content="true"/>\n\n        <meta name="X-TIKA:Parsed-By" content="org.apache.tika.parser.CompositeParser"/>\n\n        <meta name="X-TIKA:Parsed-By" content="org.apache.tika.parser.pdf.PDFParser"/>\n\n        <meta name="access_permission:can_modify" content="true"/>\n\n        <meta name="pdf:docinfo:producer" content="Microsoft: Print To PDF"/>\n\n        <meta name="pdf:docinfo:created" content="2024-11-12T18:52:48Z"/>\n\n        <title>Microsoft Word - AVISO DE ERRATA N&ordm; 001 - LAUDA.doc</title>\n\n    </head>\n\n    <body>\n        <div class="page">\n            <p/>\n\n            <p>ESTADO DE SANTA CATARINA \nPREFEITURA MUNICIPAL DE PALHO&Ccedil;A \nAVISO DE ERRATA N&ordm; 001 \nModalidade: Preg&atilde;o Eletr&ocirc;nico n&ordm; 155/2024/SMS. \nObjeto: aquisi&ccedil;&atilde;o de 01 (UM) ve&iacute;culo tipo pickup com tra&ccedil;&atilde;o \n4X4, para uso no SAMU, vinculado a Secretaria Municipal de \nSa&uacute;de do munic&iacute;pio de Palho&ccedil;a. \nJustificativa: Altera&ccedil;&atilde;o no Termo de Refer&ecirc;ncia (Anexo II). \nNova data de abertura: 28/11/2024 &agrave;s 09h00min. \nMaiores informa&ccedil;&otilde;es: Setor de Licita&ccedil;&otilde;es da Prefeitura, \nhttp://palhoca.atende.net;https://www.portaldecompraspublicas.\ncom.br/, cplpalhoca@gmail.com, (48) 3220-0300 ramais 1733 \nou 1804. \nPalho&ccedil;a, 12 de novembro de 2024. \nEDUARDO FRECCIA \nPrefeito Municipal \n </p>\n\n            <p/>\n\n        </div>\n\n    </body>\n</html>\n', 'url': 'https://www.diariomunicipal.sc.gov.br/arquivosbd/atos/2024/11/1731444194_aviso_de_errata_n_001__lauda_extrato.pdf'}, '6611484': {'titulo': 'TERMO DE HOMOLOGAÇÃO PL 180-2024 CE 05-2024 - PASSEIO PÚBLICO', 'data': '2024-11-12 16:05:39', 'cod_registro_info_sfinge': None, 'municipio': 'Ipumirim', 'entidade': 'Prefeitura Municipal de Ipumirim', 'c ...

# %%
from slugify import slugify

ground_truth_path = pathlib.Path("../resources/ground_truth.csv")
ground_truth = {}
with ground_truth_path.open() as ground_truth_file:
    reader = csv.DictReader(ground_truth_file)
    fieldnames = []
    for header in reader.fieldnames:
        header = slugify(header, separator='_')
        if header == "datahoradom":
            header = "data"
        if header == "categoriadom":
            header = "categoria"
        fieldnames.append(header)
    reader.fieldnames = fieldnames
    for row in reader:
        row = {key: (value if value != 'NULL' else None) for key, value in row.items()}
        row_id = row.pop('codigo')  # remove 'ID' and use it as a key
        ground_truth[row_id] = row
    print(fieldnames)
# Out:
# ['codigo', 'titulo', 'data', 'cod_registro_info_sfinge', 'municipio', 'entidade', 'categoria', 'modalidade', 'nr_modalidade', 'objeto', 'justificativa', 'data_abertura', 'informacoes', 'signatario', 'cargo_do_signatario']

# %%
dom_values = ['titulo', 'data', 'cod_registro_info_sfinge', 'entidade', 'categoria']
cod_registro_info_sfinge_null_amount = 0
for codigo in sample:
    if ground_truth[codigo]['cod_registro_info_sfinge'] is None:
        cod_registro_info_sfinge_null_amount += 1
print(cod_registro_info_sfinge_null_amount)
# Out:
# 13

# %%
response = client.chat(model="gemma3:27b-it-fp16", messages=[
    {
        'role': 'user',
        'content': 'Olá'
    }
])
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 response = client.chat(model="gemma3:27b-it-fp16", messages=[
#       2     {
#       3         'role': 'user',
#       4         'content': 'Olá'
#       5     }
#       6 ])
#
# File ~/Desktop/tcc/experiments/.venv/lib/python3.13/site-packages/ollama/_client.py:333, in Client.chat(self, model, messages, tools, stream, format, options, keep_alive)
#     289 def chat(
#     290   self,
#     291   model: str = '',
#    (...)    298   keep_alive: Optional[Union[float, str]] = None,
#     299 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     300   """
#     301   Create a chat response using the requested model.
#     302
#    (...)    331   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     332   """
# --> 333   return self._request(
#     334     ChatResponse,
#     335     'POST',
#     336     '/api/chat',
#     337     json=ChatRequest(
#     338       model=model,
#     339       messages=[message for message in _copy_messages(messages)],
#     340       tools=[tool for tool in _copy_tools(tools)],
#     341       stream=stream,
#     342       format=format,
#     343       options=options,
#     344       keep_alive=keep_alive,
#     345     ).model_dump(exclude_none=True),
#     346     stream=stream,
#     347   )
#
# File ~/Desktop/tcc/experiments/.venv/lib/python3.13/site-packages/ollama/_client.py:178, in Client._request(self, cls, stream, *args, **kwargs)
#     174         yield cls(**part)
#     176   return inner()
# --> 178 return cls(**self._request_raw(*args, **kwargs).json())
#
# File ~/Desktop/tcc/experiments/.venv/lib/python3.13/site-packages/ollama/_client.py:122, in Client._request_raw(self, *args, **kwargs)
#     120   return r
#     121 except httpx.HTTPStatusError as e:
# --> 122   raise ResponseError(e.response.text, e.response.status_code) from None
#     123 except httpx.ConnectError:
#     124   raise ConnectionError(CONNECTION_ERROR_MESSAGE) from None
#
# ResponseError: llama runner process has terminated: this model is not supported by your version of Ollama. You may need to upgrade (status code: 500)
